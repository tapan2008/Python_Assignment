# %% [markdown]
# Question 1:
#
# ## Create a Python class called Rectangle with attributes length and width. Implement methods to calculate the area and perimeter of the rectangle.

# %%
class rectangle:
  def __init__(self,length,width):
    self.length=length
    self.width= width
  def display(self):
    print("The length of the rectangle is", self.length)
    print("The width of the rectangle is", self.width)
  def area (self):
    return  self.length*self.width

  def perimeter(self):
    return 2*self.length+2*self.width

l=int(input("enter the length : "))
w=int(input("enter the width : "))


r1= rectangle(l,w)
print("rectanglle details are: ")
r1.display()
print("")
print("Area of the rectangle is", r1.area())
print("")
print("perimeter of the rectangle is", r1.perimeter())
print("")
# Out:
# enter the length : 10
# enter the width : 20
# rectanglle details are:
# The length of the rectangle is 10
# The width of the rectangle is 20
#
# Area of the rectangle is 200
#
# perimeter of the rectangle is 60

# %% [markdown]
# Question 2:
#
# Create a Python class called Employee with attributes name, salary, and role. Implement a method to give a salary raise to an employee.

# %%
class employee:
  def __init__(self, name, salary, role):
    self.name=name
    self.salary=salary
    self.role=role
  def display(self):
    print("The name of the emplyee is", name)
    print("The salary of the emplyee is", salary)
    print("The role of the emplyee is", role)

  def salary_raise(self):
    return salary+salary*.05

name=input("Enter the name of the elployee: ")
salary=float(input("Enter the salary of the elployee: "))
role=input("Enter the role of the elployee: ")

E1=employee(name,salary,role)
E1.display()

print("The new salary of {} is {}".format(name,E1.salary_raise()))
# Out:
# Enter the name of the elployee: Nagen
# Enter the salary of the elployee: 500.50
# Enter the role of the elployee: sweeper
# The name of the emplyee is Nagen
# The salary of the emplyee is 500.5
# The role of the emplyee is sweeper
# The new salary of Nagen is 525.525

# %% [markdown]
# Question 3:
#
# Create a Python class called BankAccount with attributes account_number and balance. Implement methods to deposit and withdraw money from the account while keeping track of the balance.

# %%
# BankAccount class
class Bank_Account:
    def __init__(self):
        self.balance=0
        print("Hello!!! Welcome to the Deposit & Withdrawal Machine")

    def deposit(self):
        amount=float(input("Enter amount to be Deposited: "))
        self.balance += amount
        print("\n Amount Deposited:",amount)

    def withdraw(self):
        amount = float(input("Enter amount to be Withdrawn: "))
        if self.balance>=amount:
            self.balance-=amount
            print("\n You Withdrew:", amount)
        else:
            print("\n Insufficient balance  ")

    def display(self):
        print("\n Net Available Balance=",self.balance)

# Driver code

# creating an object of class
s=Bank_Account()

# Calling functions with that class object
s.deposit()
s.withdraw()
s.display()
# Out:
# Hello!!! Welcome to the Deposit & Withdrawal Machine
# Enter amount to be Deposited: 1000
#
#  Amount Deposited: 1000.0
# Enter amount to be Withdrawn: 00
#
#  You Withdrew: 0.0
#
#  Net Available Balance= 1000.0

# %% [markdown]
# Question 4:
#
# Create a Python class hierarchy for shapes, including circles and rectangles. Implement a method to calculate the area of each shape.

# %%
class hierarchy:
  def __init__(self,r,l,b):
    self.r=r
    self.l=l
    self.b=b

  def display(self):
    ("The details are as below")



  def a_c(self):
    return 22/7*r**2


  def a_r(self):
    return l*b


r=int(input("Enter the radius of circle: "))
l=int(input("Enter the length of rectangle: "))
b=int(input("Enter the beadth of rectangle: "))

h1=hierarchy(r,l,b)

h1.a_c()
h1.a_r()
h1.display()
print("The area of circle is {} and the area of the rectangle is {}".format(h1.a_c(), h1.a_r()))
# Out:
# Enter the radius of circle: 7
# Enter the length of rectangle: 10
# Enter the beadth of rectangle: 20
# The area of circle is 154.0 and the area of the rectangle is 200

# %%
230
